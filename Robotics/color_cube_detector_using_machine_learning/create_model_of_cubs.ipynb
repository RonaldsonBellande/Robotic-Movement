# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import cairo

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential, Model
from keras.optimizers import RMSprop
from keras.layers import Activation, Dropout, Flatten, Dense, GlobalMaxPooling2D, Conv2D, MaxPooling2D
from keras.callbacks import CSVLogger
from livelossplot.keras import PlotLossesCallback
import efficientnet.keras as efn
import keras
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
import pickle
import sys
import numpy as np
from keras import optimizers
import os
from mlxtend.plotting import plot_confusion_matrix
import random
from PIL import Image
from contextlib import redirect_stdout
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, classification_report

# %%
image_width, image_height = 200, 200
epochs = 0
cur_epoch = 200
batch_size = 8
test_size = 30
input_shape = (image_width, image_height, 3)
file_path_train = r"/home/ronaldsonbellande/Desktop/mobile_robotics/personal_repository/color_cube_detector_using_machine_learning/training_image_cubes/"
file_path_validation = r"/home/ronaldsonbellande/Desktop/mobile_robotics/personal_repository/color_cube_detector_using_machine_learning/validation/"
file_path_test = r"/home/ronaldsonbellande/Desktop/mobile_robotics/personal_repository/color_cube_detector_using_machine_learning/testing/"

# %%
model = Sequential()
model = Sequential()

model.add(Conv2D(32, 3, 3, padding='same', input_shape=input_shape, activation='relu'))
model.add(Conv2D(32, 3, 3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, 3, 3, padding='same', activation='relu'))
model.add(Conv2D(64, 3, 3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, 3, 3, padding='same', activation='relu'))
model.add(Conv2D(128, 3, 3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), padding='same'))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy',
            optimizer=RMSprop(lr=0.0001),
            metrics=['accuracy'])

# model.compile(loss='binary_crossentropy',
#             optimizer=RMSprop(lr=0.0001),
#             metrics=['accuracy'])

# %%
model_summary = model.summary()
with open('model_summary.txt', 'w') as f:
    with redirect_stdout(f):
        model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 67, 67, 32)        896
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 23, 23, 32)        9248
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 11, 11, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 4, 4, 64)          18496
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 2, 2, 64)          36928
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 1, 1, 64)          0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 1, 1, 128)         73856
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 1, 1, 128)         147584
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 129
# _________________________________________________________________
# activation_1 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 320,161
# Trainable params: 320,161
# Non-trainable params: 0
# _________________________________________________________________

# %%
scale = 1./255
training_data_image_classification = ImageDataGenerator(rescale= scale, shear_range=0.1, zoom_range=0.1, horizontal_flip=True)
validation_data_image_classification = ImageDataGenerator(rescale= scale)
test_data_image_classification = ImageDataGenerator(rescale= scale)

# %%
training_generator = training_data_image_classification.flow_from_directory(file_path_train,
    target_size=(image_width, image_height),
    batch_size=batch_size, class_mode="binary")
# Out:
# Found 15 images belonging to 3 classes.

# %%
print(training_generator)
# Out:
# <tensorflow.python.keras.preprocessing.image.DirectoryIterator object at 0x7fe77d65d640>

# %%
validation_generator = validation_data_image_classification.flow_from_directory(file_path_validation,
    target_size=(image_width, image_height),
    batch_size=batch_size, class_mode="binary")
# Out:
# Found 9 images belonging to 3 classes.

# %%
test_generator = test_data_image_classification.flow_from_directory(file_path_test,
    target_size=(image_width, image_height),
    batch_size=1,
    class_mode="binary", 
    shuffle=False)
# Out:
# Found 9 images belonging to 3 classes.

# %%
for data_batch, labels_batch in training_generator:
    print('data batch shape:', data_batch.shape)
    print('labels batch shape:', labels_batch.shape)
    break
# Out:
# data batch shape: (8, 200, 200, 3)
# labels batch shape: (8,)

# %%
class_names = training_generator.class_indices
print(class_names)
# Out:
# {'green_cubes': 0, 'red_cubes': 1, 'yellow_cubes': 2}

# %%
 checkpoint = keras.callbacks.EarlyStopping(monitor='val_acc', patience=4, verbose=1)

# %%
trained_model = model.fit(
    training_generator,
    steps_per_epoch=len(training_generator.filenames)//training_generator.batch_size,
    initial_epoch=epochs,
    epochs=epochs + cur_epoch,
    validation_data=validation_generator,
    validation_steps=len(validation_generator.filenames)//validation_generator.batch_size,
    callbacks=[checkpoint],
    shuffle = True, verbose=1)
# Out:
# Epoch 1/200
# 1/1 [==============================] - 5s 5s/step - loss: 0.6939 - accuracy: 0.7500 - val_loss: 0.6919 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 2/200
# 1/1 [==============================] - 1s 596ms/step - loss: 0.6937 - accuracy: 0.2857 - val_loss: 0.6915 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 3/200
# 1/1 [==============================] - 0s 375ms/step - loss: 0.6905 - accuracy: 0.2500 - val_loss: 0.6900 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 4/200
# 1/1 [==============================] - 0s 314ms/step - loss: 0.6896 - accuracy: 0.4286 - val_loss: 0.6900 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 5/200
# 1/1 [==============================] - 0s 280ms/step - loss: 0.6891 - accuracy: 0.2857 - val_loss: 0.6895 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 6/200
# 1/1 [==============================] - 0s 296ms/step - loss: 0.6905 - accuracy: 0.1429 - val_loss: 0.6869 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 7/200
# 1/1 [==============================] - 1s 675ms/step - loss: 0.6892 - accuracy: 0.2500 - val_loss: 0.6860 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 8/200
# 1/1 [==============================] - 1s 504ms/step - loss: 0.6868 - accuracy: 0.1429 - val_loss: 0.6864 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 9/200
# 1/1 [==============================] - 0s 336ms/step - loss: 0.6893 - accuracy: 0.3750 - val_loss: 0.6842 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 10/200
# 1/1 [==============================] - 0s 313ms/step - loss: 0.6913 - accuracy: 0.1429 - val_loss: 0.6838 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 11/200
# 1/1 [==============================] - 0s 285ms/step - loss: 0.6862 - accuracy: 0.3750 - val_loss: 0.6867 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 12/200
# 1/1 [==============================] - 0s 328ms/step - loss: 0.6887 - accuracy: 0.2857 - val_loss: 0.6841 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 13/200
# 1/1 [==============================] - 0s 289ms/step - loss: 0.6898 - accuracy: 0.4286 - val_loss: 0.6861 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 14/200
# 1/1 [==============================] - 0s 279ms/step - loss: 0.6882 - accuracy: 0.2857 - val_loss: 0.6834 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 15/200
# 1/1 [==============================] - 0s 295ms/step - loss: 0.6881 - accuracy: 0.3750 - val_loss: 0.6855 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 16/200
# 1/1 [==============================] - 0s 289ms/step - loss: 0.6907 - accuracy: 0.2500 - val_loss: 0.6827 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 17/200
# 1/1 [==============================] - 0s 291ms/step - loss: 0.6899 - accuracy: 0.3750 - val_loss: 0.6822 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 18/200
# 1/1 [==============================] - 0s 281ms/step - loss: 0.6743 - accuracy: 0.4286 - val_loss: 0.6781 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 19/200
# 1/1 [==============================] - 0s 448ms/step - loss: 0.6717 - accuracy: 0.1429 - val_loss: 0.6823 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 20/200
# 1/1 [==============================] - 0s 310ms/step - loss: 0.6816 - accuracy: 0.4286 - val_loss: 0.6779 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 21/200
# 1/1 [==============================] - 0s 374ms/step - loss: 0.6878 - accuracy: 0.2857 - val_loss: 0.6744 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 22/200
# 1/1 [==============================] - 0s 286ms/step - loss: 0.6753 - accuracy: 0.2857 - val_loss: 0.6729 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 23/200
# 1/1 [==============================] - 0s 304ms/step - loss: 0.6815 - accuracy: 0.5714 - val_loss: 0.6794 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 24/200
# 1/1 [==============================] - 0s 322ms/step - loss: 0.6824 - accuracy: 0.3750 - val_loss: 0.6788 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 25/200
# 1/1 [==============================] - 0s 269ms/step - loss: 0.6616 - accuracy: 0.4286 - val_loss: 0.6722 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 26/200
# 1/1 [==============================] - 0s 288ms/step - loss: 0.6683 - accuracy: 0.1250 - val_loss: 0.6664 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 27/200
# 1/1 [==============================] - 0s 300ms/step - loss: 0.6811 - accuracy: 0.2857 - val_loss: 0.6696 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 28/200
# 1/1 [==============================] - 0s 306ms/step - loss: 0.6856 - accuracy: 0.3750 - val_loss: 0.6745 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 29/200
# 1/1 [==============================] - 0s 355ms/step - loss: 0.6774 - accuracy: 0.5714 - val_loss: 0.6742 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 30/200
# 1/1 [==============================] - 0s 324ms/step - loss: 0.6657 - accuracy: 0.2500 - val_loss: 0.6654 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 31/200
# 1/1 [==============================] - 0s 470ms/step - loss: 0.6542 - accuracy: 0.5000 - val_loss: 0.6698 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 32/200
# 1/1 [==============================] - 0s 300ms/step - loss: 0.6745 - accuracy: 0.4286 - val_loss: 0.6695 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 33/200
# 1/1 [==============================] - 0s 310ms/step - loss: 0.6774 - accuracy: 0.2500 - val_loss: 0.6546 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 34/200
# 1/1 [==============================] - 0s 269ms/step - loss: 0.6403 - accuracy: 0.1429 - val_loss: 0.6509 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 35/200
# 1/1 [==============================] - 0s 316ms/step - loss: 0.6772 - accuracy: 0.5714 - val_loss: 0.6558 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 36/200
# 1/1 [==============================] - 0s 374ms/step - loss: 0.6786 - accuracy: 0.2500 - val_loss: 0.6644 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 37/200
# 1/1 [==============================] - 0s 310ms/step - loss: 0.6705 - accuracy: 0.2500 - val_loss: 0.6534 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 38/200
# 1/1 [==============================] - 0s 334ms/step - loss: 0.6796 - accuracy: 0.3750 - val_loss: 0.6613 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 39/200
# 1/1 [==============================] - 0s 286ms/step - loss: 0.6684 - accuracy: 0.4286 - val_loss: 0.6497 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 40/200
# 1/1 [==============================] - 0s 289ms/step - loss: 0.6657 - accuracy: 0.4286 - val_loss: 0.6396 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 41/200
# 1/1 [==============================] - 0s 294ms/step - loss: 0.6093 - accuracy: 0.2500 - val_loss: 0.6420 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 42/200
# 1/1 [==============================] - 0s 319ms/step - loss: 0.6487 - accuracy: 0.4286 - val_loss: 0.6393 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 43/200
# 1/1 [==============================] - 0s 298ms/step - loss: 0.6623 - accuracy: 0.2500 - val_loss: 0.6269 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 44/200
# 1/1 [==============================] - 0s 288ms/step - loss: 0.5926 - accuracy: 0.2500 - val_loss: 0.6452 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 45/200
# 1/1 [==============================] - 0s 270ms/step - loss: 0.6307 - accuracy: 0.4286 - val_loss: 0.6141 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 46/200
# 1/1 [==============================] - 0s 267ms/step - loss: 0.6891 - accuracy: 0.1429 - val_loss: 0.6425 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 47/200
# 1/1 [==============================] - 0s 271ms/step - loss: 0.6365 - accuracy: 0.4286 - val_loss: 0.6392 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 48/200
# 1/1 [==============================] - 0s 342ms/step - loss: 0.6716 - accuracy: 0.3750 - val_loss: 0.6071 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 49/200
# 1/1 [==============================] - 0s 261ms/step - loss: 0.6025 - accuracy: 0.2857 - val_loss: 0.6122 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 50/200
# 1/1 [==============================] - 0s 261ms/step - loss: 0.5966 - accuracy: 0.2857 - val_loss: 0.6274 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 51/200
# 1/1 [==============================] - 0s 276ms/step - loss: 0.5913 - accuracy: 0.2857 - val_loss: 0.5813 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 52/200
# 1/1 [==============================] - 0s 271ms/step - loss: 0.5785 - accuracy: 0.2857 - val_loss: 0.5891 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 53/200
# 1/1 [==============================] - 0s 283ms/step - loss: 0.4675 - accuracy: 0.4286 - val_loss: 0.6045 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 54/200
# 1/1 [==============================] - 0s 329ms/step - loss: 0.6248 - accuracy: 0.2500 - val_loss: 0.5702 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 55/200
# 1/1 [==============================] - 0s 355ms/step - loss: 0.5627 - accuracy: 0.0000e+00 - val_loss: 0.5401 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 56/200
# 1/1 [==============================] - 0s 289ms/step - loss: 0.5312 - accuracy: 0.1250 - val_loss: 0.5871 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 57/200
# 1/1 [==============================] - 0s 315ms/step - loss: 0.5751 - accuracy: 0.3750 - val_loss: 0.5753 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 58/200
# 1/1 [==============================] - 0s 277ms/step - loss: 0.5318 - accuracy: 0.4286 - val_loss: 0.5659 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 59/200
# 1/1 [==============================] - 0s 285ms/step - loss: 0.4227 - accuracy: 0.2857 - val_loss: 0.5115 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 60/200
# 1/1 [==============================] - 0s 272ms/step - loss: 0.4294 - accuracy: 0.4286 - val_loss: 0.5389 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 61/200
# 1/1 [==============================] - 0s 291ms/step - loss: 0.5326 - accuracy: 0.5000 - val_loss: 0.4829 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 62/200
# 1/1 [==============================] - 0s 284ms/step - loss: 0.5774 - accuracy: 0.4286 - val_loss: 0.5295 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 63/200
# 1/1 [==============================] - 0s 294ms/step - loss: 0.4874 - accuracy: 0.6250 - val_loss: 0.5113 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 64/200
# 1/1 [==============================] - 0s 281ms/step - loss: 0.5266 - accuracy: 0.4286 - val_loss: 0.5118 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 65/200
# 1/1 [==============================] - 0s 277ms/step - loss: 0.4245 - accuracy: 0.3750 - val_loss: 0.4949 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 66/200
# 1/1 [==============================] - 0s 287ms/step - loss: 0.5921 - accuracy: 0.4286 - val_loss: 0.3785 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 67/200
# 1/1 [==============================] - 0s 301ms/step - loss: 0.4286 - accuracy: 0.1250 - val_loss: 0.3547 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 68/200
# 1/1 [==============================] - 0s 281ms/step - loss: 0.4926 - accuracy: 0.4286 - val_loss: 0.3362 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 69/200
# 1/1 [==============================] - 0s 266ms/step - loss: 0.4840 - accuracy: 0.1429 - val_loss: 0.3120 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 70/200
# 1/1 [==============================] - 0s 279ms/step - loss: 0.5512 - accuracy: 0.3750 - val_loss: 0.3027 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 71/200
# 1/1 [==============================] - 0s 286ms/step - loss: 0.2074 - accuracy: 0.2500 - val_loss: 0.2592 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 72/200
# 1/1 [==============================] - 0s 270ms/step - loss: 0.4281 - accuracy: 0.2857 - val_loss: 0.3842 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 73/200
# 1/1 [==============================] - 0s 373ms/step - loss: 0.2570 - accuracy: 0.2500 - val_loss: 0.3763 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 74/200
# 1/1 [==============================] - 0s 264ms/step - loss: 0.4449 - accuracy: 0.4286 - val_loss: 0.3458 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 75/200
# 1/1 [==============================] - 0s 286ms/step - loss: 0.3932 - accuracy: 0.2500 - val_loss: 0.3290 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 76/200
# 1/1 [==============================] - 0s 271ms/step - loss: 0.4748 - accuracy: 0.5714 - val_loss: 0.3151 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 77/200
# 1/1 [==============================] - 0s 317ms/step - loss: 0.2366 - accuracy: 0.3750 - val_loss: 0.0796 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 78/200
# 1/1 [==============================] - 0s 339ms/step - loss: 0.1691 - accuracy: 0.1429 - val_loss: 0.2765 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 79/200
# 1/1 [==============================] - 0s 296ms/step - loss: 0.5245 - accuracy: 0.2500 - val_loss: 0.0324 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 80/200
# 1/1 [==============================] - 0s 296ms/step - loss: -0.0740 - accuracy: 0.3750 - val_loss: 0.2114 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 81/200
# 1/1 [==============================] - 0s 271ms/step - loss: -0.0977 - accuracy: 0.1429 - val_loss: 0.0037 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 82/200
# 1/1 [==============================] - 0s 292ms/step - loss: 0.6416 - accuracy: 0.2857 - val_loss: 0.1968 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 83/200
# 1/1 [==============================] - 0s 298ms/step - loss: 0.3261 - accuracy: 0.2500 - val_loss: 0.1869 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 84/200
# 1/1 [==============================] - 0s 276ms/step - loss: 0.6384 - accuracy: 0.5714 - val_loss: 0.1597 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 85/200
# 1/1 [==============================] - 0s 284ms/step - loss: 0.5701 - accuracy: 0.5714 - val_loss: 0.1837 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 86/200
# 1/1 [==============================] - 0s 302ms/step - loss: 0.3813 - accuracy: 0.3750 - val_loss: -0.1408 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 87/200
# 1/1 [==============================] - 0s 278ms/step - loss: 0.0539 - accuracy: 0.4286 - val_loss: 0.1083 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 88/200
# 1/1 [==============================] - 0s 292ms/step - loss: 0.4497 - accuracy: 0.1429 - val_loss: -0.0984 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 89/200
# 1/1 [==============================] - 0s 282ms/step - loss: 0.0403 - accuracy: 0.4286 - val_loss: -0.2528 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 90/200
# 1/1 [==============================] - 0s 281ms/step - loss: 0.1362 - accuracy: 0.4286 - val_loss: -0.1854 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 91/200
# 1/1 [==============================] - 0s 255ms/step - loss: -0.9033 - accuracy: 0.2857 - val_loss: -0.3973 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 92/200
# 1/1 [==============================] - 0s 305ms/step - loss: -0.3101 - accuracy: 0.3750 - val_loss: -0.4592 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 93/200
# 1/1 [==============================] - 0s 297ms/step - loss: -0.2361 - accuracy: 0.5000 - val_loss: -0.3767 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 94/200
# 1/1 [==============================] - 0s 290ms/step - loss: -0.0482 - accuracy: 0.5000 - val_loss: -0.5482 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 95/200
# 1/1 [==============================] - 0s 283ms/step - loss: 0.1063 - accuracy: 0.2857 - val_loss: -0.4277 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 96/200
# 1/1 [==============================] - 0s 328ms/step - loss: -0.1506 - accuracy: 0.3750 - val_loss: -0.4651 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 97/200
# 1/1 [==============================] - 0s 270ms/step - loss: -0.8074 - accuracy: 0.5714 - val_loss: -0.7408 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 98/200
# 1/1 [==============================] - 0s 307ms/step - loss: -0.4221 - accuracy: 0.5000 - val_loss: -0.5947 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 99/200
# 1/1 [==============================] - 0s 291ms/step - loss: 0.7473 - accuracy: 0.2857 - val_loss: -0.5742 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 100/200
# 1/1 [==============================] - 0s 286ms/step - loss: -0.4452 - accuracy: 0.2500 - val_loss: -0.6339 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 101/200
# 1/1 [==============================] - 0s 290ms/step - loss: -0.9400 - accuracy: 0.2500 - val_loss: -0.7161 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 102/200
# 1/1 [==============================] - 0s 311ms/step - loss: -0.7354 - accuracy: 0.5000 - val_loss: -0.7821 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 103/200
# 1/1 [==============================] - 0s 285ms/step - loss: 0.3885 - accuracy: 0.4286 - val_loss: -0.2669 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 104/200
# 1/1 [==============================] - 0s 275ms/step - loss: -0.2935 - accuracy: 0.3750 - val_loss: -1.0211 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 105/200
# 1/1 [==============================] - 0s 278ms/step - loss: -1.3754 - accuracy: 0.4286 - val_loss: -0.9152 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 106/200
# 1/1 [==============================] - 0s 265ms/step - loss: -1.8461 - accuracy: 0.1429 - val_loss: -1.0215 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 107/200
# 1/1 [==============================] - 0s 283ms/step - loss: -2.0039 - accuracy: 0.3750 - val_loss: -1.1339 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 108/200
# 1/1 [==============================] - 0s 315ms/step - loss: 0.6821 - accuracy: 0.3750 - val_loss: -1.1127 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 109/200
# 1/1 [==============================] - 0s 350ms/step - loss: -1.0485 - accuracy: 0.4286 - val_loss: -1.4311 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 110/200
# 1/1 [==============================] - 0s 287ms/step - loss: -2.4984 - accuracy: 0.2500 - val_loss: -1.3074 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 111/200
# 1/1 [==============================] - 0s 285ms/step - loss: -2.6239 - accuracy: 0.5714 - val_loss: -1.4266 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 112/200
# 1/1 [==============================] - 0s 310ms/step - loss: -1.0005 - accuracy: 0.3750 - val_loss: -0.6329 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 113/200
# 1/1 [==============================] - 0s 316ms/step - loss: -1.8077 - accuracy: 0.3750 - val_loss: -1.9083 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 114/200
# 1/1 [==============================] - 0s 325ms/step - loss: -1.3799 - accuracy: 0.3750 - val_loss: -1.6563 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 115/200
# 1/1 [==============================] - 0s 287ms/step - loss: -2.9902 - accuracy: 0.2500 - val_loss: -0.7773 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 116/200
# 1/1 [==============================] - 0s 281ms/step - loss: -1.4655 - accuracy: 0.4286 - val_loss: -1.8770 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 117/200
# 1/1 [==============================] - 0s 299ms/step - loss: -2.1395 - accuracy: 0.2500 - val_loss: -1.9884 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 118/200
# 1/1 [==============================] - 0s 314ms/step - loss: 0.7364 - accuracy: 0.5000 - val_loss: -1.9575 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 119/200
# 1/1 [==============================] - 0s 296ms/step - loss: 0.7503 - accuracy: 0.1250 - val_loss: -0.9585 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 120/200
# 1/1 [==============================] - 0s 285ms/step - loss: -3.4585 - accuracy: 0.2857 - val_loss: -2.0890 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 121/200
# 1/1 [==============================] - 0s 355ms/step - loss: 0.0361 - accuracy: 0.3750 - val_loss: -0.8885 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 122/200
# 1/1 [==============================] - 1s 571ms/step - loss: -1.9960 - accuracy: 0.1429 - val_loss: -2.7645 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 123/200
# 1/1 [==============================] - 0s 350ms/step - loss: -3.6745 - accuracy: 0.1250 - val_loss: -1.0533 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 124/200
# 1/1 [==============================] - 0s 393ms/step - loss: -2.6470 - accuracy: 0.2500 - val_loss: -2.9765 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 125/200
# 1/1 [==============================] - 0s 350ms/step - loss: -0.2282 - accuracy: 0.5714 - val_loss: -1.1255 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 126/200
# 1/1 [==============================] - 0s 397ms/step - loss: -0.7362 - accuracy: 0.3750 - val_loss: -1.1023 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 127/200
# 1/1 [==============================] - 0s 431ms/step - loss: -4.3184 - accuracy: 0.2500 - val_loss: -1.1848 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 128/200
# 1/1 [==============================] - 0s 356ms/step - loss: -3.5657 - accuracy: 0.4286 - val_loss: -1.2607 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 129/200
# 1/1 [==============================] - 0s 342ms/step - loss: 1.7272 - accuracy: 0.3750 - val_loss: -1.4541 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 130/200
# 1/1 [==============================] - 0s 345ms/step - loss: 0.1035 - accuracy: 0.4286 - val_loss: -2.8723 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 131/200
# 1/1 [==============================] - 0s 341ms/step - loss: -3.8069 - accuracy: 0.1429 - val_loss: -3.6374 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 132/200
# 1/1 [==============================] - 0s 311ms/step - loss: -2.7581 - accuracy: 0.2857 - val_loss: -3.8042 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 133/200
# 1/1 [==============================] - 0s 356ms/step - loss: -2.6297 - accuracy: 0.5000 - val_loss: -3.9660 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 134/200
# 1/1 [==============================] - 0s 324ms/step - loss: -0.2649 - accuracy: 0.2857 - val_loss: -3.3686 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 135/200
# 1/1 [==============================] - 0s 349ms/step - loss: -2.2702 - accuracy: 0.1429 - val_loss: -1.5875 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 136/200
# 1/1 [==============================] - 0s 358ms/step - loss: -1.1197 - accuracy: 0.5000 - val_loss: -1.8222 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 137/200
# 1/1 [==============================] - 0s 339ms/step - loss: -4.3740 - accuracy: 0.3750 - val_loss: -4.4645 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 138/200
# 1/1 [==============================] - 0s 325ms/step - loss: -5.1729 - accuracy: 0.2857 - val_loss: -4.0663 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 139/200
# 1/1 [==============================] - 0s 344ms/step - loss: -2.5659 - accuracy: 0.4286 - val_loss: -4.2133 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 140/200
# 1/1 [==============================] - 0s 334ms/step - loss: -7.2748 - accuracy: 0.4286 - val_loss: -4.5627 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 141/200
# 1/1 [==============================] - 0s 371ms/step - loss: -7.9085 - accuracy: 0.3750 - val_loss: -4.9205 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 142/200
# 1/1 [==============================] - 0s 320ms/step - loss: -6.5158 - accuracy: 0.5714 - val_loss: -5.2057 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 143/200
# 1/1 [==============================] - 0s 394ms/step - loss: -2.6733 - accuracy: 0.2500 - val_loss: -6.6527 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 144/200
# 1/1 [==============================] - 0s 344ms/step - loss: -6.8809 - accuracy: 0.3750 - val_loss: -5.6587 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 145/200
# 1/1 [==============================] - 0s 338ms/step - loss: -0.1096 - accuracy: 0.4286 - val_loss: -5.6596 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 146/200
# 1/1 [==============================] - 0s 322ms/step - loss: -8.1969 - accuracy: 0.1429 - val_loss: -6.0257 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 147/200
# 1/1 [==============================] - 0s 325ms/step - loss: -8.1604 - accuracy: 0.2857 - val_loss: -2.8822 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 148/200
# 1/1 [==============================] - 0s 342ms/step - loss: -9.1292 - accuracy: 0.5000 - val_loss: -8.4587 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 149/200
# 1/1 [==============================] - 0s 361ms/step - loss: 7.1547 - accuracy: 0.3750 - val_loss: -2.8222 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 150/200
# 1/1 [==============================] - 0s 370ms/step - loss: -0.5602 - accuracy: 0.1429 - val_loss: -2.8468 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 151/200
# 1/1 [==============================] - 0s 379ms/step - loss: 0.0565 - accuracy: 0.2500 - val_loss: -7.6544 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 152/200
# 1/1 [==============================] - 0s 345ms/step - loss: -3.0694 - accuracy: 0.3750 - val_loss: -6.6597 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 153/200
# 1/1 [==============================] - 0s 359ms/step - loss: -0.6081 - accuracy: 0.5714 - val_loss: -7.8282 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 154/200
# 1/1 [==============================] - 0s 380ms/step - loss: -6.8664 - accuracy: 0.3750 - val_loss: -8.7232 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 155/200
# 1/1 [==============================] - 0s 343ms/step - loss: 0.8883 - accuracy: 0.4286 - val_loss: -3.2199 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 156/200
# 1/1 [==============================] - 0s 348ms/step - loss: -5.6830 - accuracy: 0.2500 - val_loss: -3.7840 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 157/200
# 1/1 [==============================] - 0s 357ms/step - loss: -2.1062 - accuracy: 0.5714 - val_loss: -8.6565 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 158/200
# 1/1 [==============================] - 0s 364ms/step - loss: -12.2172 - accuracy: 0.4286 - val_loss: -4.1352 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 159/200
# 1/1 [==============================] - 0s 342ms/step - loss: -8.7479 - accuracy: 0.6250 - val_loss: -4.3577 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 160/200
# 1/1 [==============================] - 0s 356ms/step - loss: -8.3167 - accuracy: 0.2500 - val_loss: -10.3276 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 161/200
# 1/1 [==============================] - 0s 357ms/step - loss: -4.6222 - accuracy: 0.4286 - val_loss: -4.6948 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 162/200
# 1/1 [==============================] - 0s 355ms/step - loss: -0.3014 - accuracy: 0.6250 - val_loss: -4.7099 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 163/200
# 1/1 [==============================] - 0s 327ms/step - loss: -0.2557 - accuracy: 0.4286 - val_loss: -9.0913 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 164/200
# 1/1 [==============================] - 0s 371ms/step - loss: -2.6979 - accuracy: 0.5000 - val_loss: -10.8352 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 165/200
# 1/1 [==============================] - 0s 356ms/step - loss: -20.1732 - accuracy: 0.1429 - val_loss: -10.0892 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 166/200
# 1/1 [==============================] - 0s 364ms/step - loss: -16.0242 - accuracy: 0.2500 - val_loss: -10.7537 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 167/200
# 1/1 [==============================] - 0s 339ms/step - loss: -6.7386 - accuracy: 0.2500 - val_loss: -5.7417 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 168/200
# 1/1 [==============================] - 0s 365ms/step - loss: -21.0960 - accuracy: 0.2857 - val_loss: -14.7168 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 169/200
# 1/1 [==============================] - 0s 390ms/step - loss: -2.8749 - accuracy: 0.4286 - val_loss: -5.5307 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 170/200
# 1/1 [==============================] - 0s 366ms/step - loss: -9.9162 - accuracy: 0.2500 - val_loss: -15.3974 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 171/200
# 1/1 [==============================] - 0s 340ms/step - loss: -19.3702 - accuracy: 0.2857 - val_loss: -5.8057 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 172/200
# 1/1 [==============================] - 0s 345ms/step - loss: -7.7136 - accuracy: 0.2857 - val_loss: -13.5211 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 173/200
# 1/1 [==============================] - 0s 350ms/step - loss: -2.4238 - accuracy: 0.2857 - val_loss: -16.8611 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 174/200
# 1/1 [==============================] - 0s 379ms/step - loss: -20.4509 - accuracy: 0.5000 - val_loss: -6.6696 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 175/200
# 1/1 [==============================] - 0s 328ms/step - loss: -0.2742 - accuracy: 0.2857 - val_loss: -16.9115 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 176/200
# 1/1 [==============================] - 0s 335ms/step - loss: 5.2809 - accuracy: 0.2857 - val_loss: -16.5754 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 177/200
# 1/1 [==============================] - 0s 356ms/step - loss: 3.8277 - accuracy: 0.3750 - val_loss: -16.3139 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 178/200
# 1/1 [==============================] - 0s 381ms/step - loss: -18.0601 - accuracy: 0.2500 - val_loss: -7.7657 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 179/200
# 1/1 [==============================] - 0s 391ms/step - loss: -11.7937 - accuracy: 0.5000 - val_loss: -6.8629 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 180/200
# 1/1 [==============================] - 0s 358ms/step - loss: -13.5408 - accuracy: 0.3750 - val_loss: -18.6704 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 181/200
# 1/1 [==============================] - 0s 325ms/step - loss: -22.8577 - accuracy: 0.2857 - val_loss: -19.9178 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 182/200
# 1/1 [==============================] - 0s 343ms/step - loss: 1.4534 - accuracy: 0.4286 - val_loss: -19.8214 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 183/200
# 1/1 [==============================] - 0s 341ms/step - loss: -28.8446 - accuracy: 0.1429 - val_loss: -22.3471 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 184/200
# 1/1 [==============================] - 0s 369ms/step - loss: -39.9549 - accuracy: 0.3750 - val_loss: -19.4883 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 185/200
# 1/1 [==============================] - 0s 362ms/step - loss: -21.3760 - accuracy: 0.2857 - val_loss: -20.2971 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 186/200
# 1/1 [==============================] - 0s 344ms/step - loss: -11.3494 - accuracy: 0.2857 - val_loss: -9.1821 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 187/200
# 1/1 [==============================] - 0s 340ms/step - loss: -27.3705 - accuracy: 0.4286 - val_loss: -25.4795 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 188/200
# 1/1 [==============================] - 0s 414ms/step - loss: -13.7280 - accuracy: 0.5000 - val_loss: -10.2913 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 189/200
# 1/1 [==============================] - 0s 392ms/step - loss: 0.7243 - accuracy: 0.2500 - val_loss: -22.2461 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 190/200
# 1/1 [==============================] - 0s 402ms/step - loss: -28.1727 - accuracy: 0.3750 - val_loss: -12.1853 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 191/200
# 1/1 [==============================] - 0s 409ms/step - loss: -30.5230 - accuracy: 0.1429 - val_loss: -10.8555 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 192/200
# 1/1 [==============================] - 0s 396ms/step - loss: -8.1263 - accuracy: 0.4286 - val_loss: -11.0069 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 193/200
# 1/1 [==============================] - 0s 376ms/step - loss: -14.4211 - accuracy: 0.4286 - val_loss: -11.2836 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 194/200
# 1/1 [==============================] - 0s 367ms/step - loss: -14.9705 - accuracy: 0.5000 - val_loss: -11.5799 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 195/200
# 1/1 [==============================] - 0s 370ms/step - loss: -12.4120 - accuracy: 0.3750 - val_loss: -31.1199 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 196/200
# 1/1 [==============================] - 0s 410ms/step - loss: -5.1003 - accuracy: 0.3750 - val_loss: -33.0977 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 197/200
# 1/1 [==============================] - 0s 371ms/step - loss: -53.6155 - accuracy: 0.2857 - val_loss: -28.8752 - val_accuracy: 0.2500
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 198/200
# 1/1 [==============================] - 0s 377ms/step - loss: -20.2377 - accuracy: 0.3750 - val_loss: -36.5830 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 199/200
# 1/1 [==============================] - 0s 366ms/step - loss: -11.7642 - accuracy: 0.3750 - val_loss: -14.0453 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 200/200
# 1/1 [==============================] - 0s 381ms/step - loss: -52.3444 - accuracy: 0.2500 - val_loss: -16.8178 - val_accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy

# %%
model.save_weights("CNN_cube_detector.h5")

# %%
xlabel = 'Epoch'
legends = ['Training', 'Validation']
ylim_pad = [0.01, 0.1]
plt.figure(figsize=(15, 5))
y1 = trained_model.history['accuracy']
y2 = trained_model.history['val_accuracy']

min_y = min(min(y1), min(y2))-ylim_pad[0]
max_y = max(max(y1), max(y2))+ylim_pad[0]


plt.subplot(121)
plt.plot(y1)
plt.plot(y2)
plt.title('Model Accuracy', fontsize=17)
plt.xlabel(xlabel, fontsize=15)
plt.ylabel('Accuracy', fontsize=15)
plt.ylim(min_y, max_y)
plt.legend(legends, loc='upper left')
plt.grid()
    
y1 = trained_model.history['loss']
y2 = trained_model.history['val_loss']
min_y = min(min(y1), min(y2))-ylim_pad[1]
max_y = max(max(y1), max(y2))+ylim_pad[1]
    
plt.subplot(122)
plt.plot(y1)
plt.plot(y2)

plt.title('Model Loss', fontsize=17)
plt.xlabel(xlabel, fontsize=15)
plt.ylabel('Loss', fontsize=15)
plt.ylim(min_y, max_y)
plt.legend(legends, loc='upper left')
plt.grid()                      
plt.show()

# %%
print("results")
result  = model.evaluate(test_generator, steps=len(test_generator), verbose=2)

print("%s%.2f  "% ("Loss     : ", result[0]))
print("%s%.2f%s"% ("Accuracy : ", result[1]*100, "%"))
# Out:
# results
# 9/9 - 0s - loss: -2.8299e+01 - accuracy: 0.3333
# Loss     : -28.30
# Accuracy : 33.33%

# %%
classes = test_generator.class_indices
classes
# Out:
# {'green_cubes': 0, 'red_cubes': 1, 'yellow_cubes': 2}

# %%
y_pred = model.predict(test_generator, steps=len(test_generator), verbose=1)
# y_pred = y_pred.argmax(axis=-1)
y_pred = y_pred.reshape(1,9)
y_pred = y_pred[0]
y_true=test_generator.classes
print(y_pred)
# Out:
# 9/9 [==============================] - 0s 5ms/step
# [1. 1. 1. 1. 1. 1. 1. 1. 1.]

# %%
#metrics.f1_score(y_true, y_pred, average='weighted', labels=np.unique(y_pred))

# %%
image_file_name = "/home/ronaldsonbellande/Desktop/mobile_robotics/personal_repository/color_cube_detector_using_machine_learning/"

file_path = 'CNN_cube_detector.h5'
title = file_path.split("/")
model_title = "/".join([i for i in title[3:]])

precision = precision_score(y_true, y_pred, average="weighted") 
recall = recall_score(y_true, y_pred, average="weighted") 
f1 = f1_score(y_true, y_pred, average="weighted") 

print("-"*90)
print("Derived Report")
print("-"*90)
print("%s%.2f%s"% ("Precision     : ", precision*100, "%"))
print("%s%.2f%s"% ("Recall        : ", recall*100,    "%"))
print("%s%.2f%s"% ("F1-Score      : ", f1*100,        "%"))
print("-"*90)
print("\n\n")

CM = confusion_matrix(y_true*10, y_pred*10)
fig, ax = plot_confusion_matrix(conf_mat=CM , figsize=(10,8), hide_ticks=True, cmap=plt.cm.Blues)
plt.xticks(range(len(classes)), classes, fontsize=10)
plt.yticks(range(len(classes)), classes, fontsize=10)
plt.title("Confusion Matrix for Model File (Test Dataset): \n"+model_title, fontsize=10)
fig.savefig(image_file_name, dpi=100)
plt.show()
    

cls_report_print = classification_report(y_true, y_pred, target_names=classes)

cls_report = classification_report(y_true, y_pred, target_names=classes, output_dict=True)

print("\n\n")
print("-"*90)
print("Report for Model File: ", model_title)
print("-"*90)
print(cls_report_print)
print("-"*90)
# Out:
# ------------------------------------------------------------------------------------------
# Derived Report
# ------------------------------------------------------------------------------------------
# Precision     : 11.11%
# Recall        : 33.33%
# F1-Score      : 16.67%
# ------------------------------------------------------------------------------------------
# /home/ronaldsonbellande/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ------------------------------------------------------------------------------------------
# Report for Model File:
# ------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#  green_cubes       0.33      1.00      0.50         3
#    red_cubes       0.00      0.00      0.00         3
# yellow_cubes       0.00      0.00      0.00         3
#
#     accuracy                           0.33         9
#    macro avg       0.11      0.33      0.17         9
# weighted avg       0.11      0.33      0.17         9
#
# ------------------------------------------------------------------------------------------
# /home/ronaldsonbellande/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/ronaldsonbellande/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/ronaldsonbellande/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/ronaldsonbellande/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/ronaldsonbellande/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/ronaldsonbellande/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
